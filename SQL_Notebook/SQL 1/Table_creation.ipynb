# %%
# %reload_ext sql
# %sql mysql+mysqlconnector://root:Sakthivaishu@localhost:3306/

# %% [markdown]
# ####CTAS

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 24 rows affected.
# [('besant',),
#  ('class',),
#  ('college',),
#  ('company',),
#  ('emp_info',),
#  ('emp_table',),
#  ('emp_work',),
#  ('exams_result',),
#  ('hotel',),
#  ('information_schema',),
#  ('joins',),
#  ('mysql',),
#  ('performance_schema',),
#  ('poorvika',),
#  ('sakila',),
#  ('school',),
#  ('show_room',),
#  ('students',),
#  ('swiggy_tp',),
#  ('sys',),
#  ('technology',),
#  ('tp_930_de',),
#  ('weekend',),
#  ('world',)]

# %%
# %%sql
# use tp_930_de;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# select * from tp_930_de.Employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 100 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem'),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore'),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore'),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli'),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur'),
# ...

# %%
# %%sql
# create table tp_930_de.employees_chennai as
# select * from tp_930_de.Employees
# where location = "Chennai";
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 6 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 6 rows affected.
# [('emp',),
#  ('employees',),
#  ('employees_chennai',),
#  ('empployees_chennai',),
#  ('orders',),
#  ('test',)]

# %% [markdown]
# %%sql
# drop table tp_930_de.empployees_chennai;

# %% [markdown]
# #### Temporary table

# %%
# %%sql
# create temporary table test_table(
#     Name varchar(100),
#     Age int,
#     Contact bigint
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# insert into test_table (Name, Age, Contact)
# values
# ("Vaishu",78, 78787878779);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 1 rows affected.
# []

# %%
# %%sql
# select * from tp_930_de.test_table;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'tp_930_de.test_table' doesn't exist
# [SQL: select * from tp_930_de.test_table;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# create temporary table tp_930_de.emp_detail as
# select * from tp_930_de.employees
# where department = "IT";
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 6 rows affected.
# []

# %%
# %%sql
# alter table tp_930_de.Employees
# add column Increment int;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# select * from tp_930_de.Employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 100 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore', 0),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem', 0),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore', 0),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore', 0),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy', 0),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy', 0),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore', 0),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore', 0),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli', 0),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur', 0),
# ...

# %%
# %%sql
# alter table tp_930_de.Employees
# drop column Increment;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# select * from tp_930_de.Employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 100 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem'),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore'),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore'),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli'),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur'),
# ...

# %%
# %%sql
# alter table tp_930_de.Employees
# add column Increment int;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# update tp_930_de.Employees
# set increment = 10
# where name = "Saroja";
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 2 rows affected.
# []

# %%
# %%sql
# select * from tp_930_de.Employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 100 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore', 10),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem', None),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore', None),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore', None),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy', None),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy', None),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore', None),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore', None),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli', None),
# ...

# %%
# %%sql
# select * from tp_930_de.Employees
# where increment is not null;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 2 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore', 10),
#  (80, 'Saroja', 50, 'Female', Decimal('66939.16'), 'HR', '9200471138', 'Madurai', 10)]

# %%
# %%sql
# select * from tp_930_de.Employees
# where increment is null
# order by empid asc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 98 rows affected.
# [(2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem', None),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore', None),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore', None),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy', None),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy', None),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore', None),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore', None),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli', None),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur', None),
# ...

# %%
# %%sql
# insert into tp_930_de.Employees (empid) values (101);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 1 rows affected.
# []

# %%
# %%sql
# select * from tp_930_de.Employees
# order by empid desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 101 rows affected.
# [(101, None, None, None, None, None, None, None, None),
#  (100, 'Deepa', 46, 'Female', Decimal('74664.39'), 'Sales', '9521818835', 'Erode', None),
#  (99, 'Priya', 41, 'Male', Decimal('79105.77'), 'Logistics', '9751613696', 'Thanjavur', None),
#  (98, 'Ramesh', 46, 'Male', Decimal('49897.57'), 'Support', '9159696641', 'Vellore', None),
#  (97, 'Nirmala', 37, 'Female', Decimal('41249.79'), 'IT', '9762268388', 'Erode', None),
#  (96, 'Revathi', 39, 'Female', Decimal('57154.73'), 'Marketing', '9036900343', 'Madurai', None),
#  (95, 'Swathi', 24, 'Male', Decimal('36768.23'), 'Admin', '9797643815', 'Vellore', None),
#  (94, 'Manoj', 54, 'Male', Decimal('45095.55'), 'Support', '9525459910', 'Madurai', None),
#  (93, 'Karthik', 32, 'Female', Decimal('71215.90'), 'Marketing', '9550229612', 'Chennai', None),
#  (92, 'Vasanthi', 56, 'Female', Decimal('24190.83'), 'Marketing', '9936899809', 'Salem', None),
# ...

# %%
# %%sql
# delete from tp_930_de.Employees
# where empid = 101;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 1 rows affected.
# []

# %%
# %%sql
# desc tp_930_de.Employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 9 rows affected.
# [('EmpID', 'int', 'NO', 'PRI', None, ''),
#  ('Name', 'varchar(100)', 'YES', '', None, ''),
#  ('Age', 'int', 'YES', '', None, ''),
#  ('Gender', 'varchar(10)', 'YES', '', None, ''),
#  ('salary', 'decimal(10,2)', 'YES', '', None, ''),
#  ('Department', 'varchar(10)', 'YES', '', None, ''),
#  ('Number', 'varchar(10)', 'YES', '', None, ''),
#  ('Location', 'varchar(100)', 'YES', '', None, ''),
#  ('Increment', 'int', 'YES', '', None, '')]
