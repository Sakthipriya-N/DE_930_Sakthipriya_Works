# %%
# %reload_ext sql
# %sql mysql+mysqlconnector://root:Sakthivaishu@localhost:3306/

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 23 rows affected.
# [('besant',),
#  ('class',),
#  ('college',),
#  ('company',),
#  ('emp_info',),
#  ('emp_table',),
#  ('emp_work',),
#  ('exams_result',),
#  ('hotel',),
#  ('information_schema',),
#  ('joins',),
#  ('mysql',),
#  ('performance_schema',),
#  ('poorvika',),
#  ('sakila',),
#  ('school',),
#  ('show_room',),
#  ('students',),
#  ('sys',),
#  ('technology',),
#  ('tp_930_de',),
#  ('weekend',),
#  ('world',)]

# %%
# %%sql
# create table tp_930_de.Employees(
#     EmpID int primary key,
# Name varchar(100),
# Age int,
# Gender varchar(10),
# salary decimal(10,2),
# Department varchar (10),
# Number varchar (10),
# Location varchar(100)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# show tp_930_de.table;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'tp_930_de.table' at line 1
# [SQL: show tp_930_de.table;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# select * from tp_930_de.emp;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# Out:
#   Cell In[12], line 1
#     insert into employee
#            ^
# SyntaxError: invalid syntax

# %%
# %%sql
# insert into tp_930_de.Employees
# values
# (1, 'Saroja', 28, 'Male', 74324.04, 'Sales', '9321819600', 'Coimbatore'),
# (2, 'Vignesh', 35, 'Male', 59899.61, 'R&D', '9637940265', 'Salem'),
# (3, 'Naveen', 34, 'Female', 23176.82, 'Admin', '9155940781', 'Vellore'),
# (4, 'Deepa', 56, 'Female', 81352.37, 'Logistics', '9593103413', 'Coimbatore'),
# (5, 'Malathi', 38, 'Female', 65854.76, 'Operations', '9255341928', 'Trichy'),
# (6, 'Swathi', 50, 'Female', 36595.83, 'R&D', '9350305641', 'Trichy'),
# (7, 'Palani', 41, 'Male', 67435.09, 'Admin', '9724238849', 'Vellore'),
# (8, 'Krishnan', 46, 'Female', 32545.66, 'Finance', '9871012269', 'Coimbatore'),
# (9, 'Karthika', 45, 'Female', 57329.15, 'R&D', '9018451462', 'Tirunelveli'),
# (10, 'Gopal', 37, 'Male', 92751.05, 'Finance', '9814893252', 'Thanjavur'),
# (11, 'Tamil', 54, 'Male', 62915.57, 'Support', '9015430391', 'Coimbatore'),
# (12, 'Parvathi', 52, 'Male', 93238.76, 'R&D', '9227824896', 'Trichy'),
# (13, 'Mala', 33, 'Female', 46919.38, 'Operations', '9787133150', 'Tiruppur'),
# (14, 'Ravi', 35, 'Male', 15575.27, 'IT', '9310518347', 'Trichy'),
# (15, 'Mala', 29, 'Female', 34439.78, 'Support', '9631165667', 'Chennai'),
# (16, 'Selva', 27, 'Male', 47209.7, 'Operations', '9133387262', 'Salem'),
# (17, 'Rekha', 36, 'Male', 50450.46, 'R&D', '9108013267', 'Tirunelveli'),
# (18, 'Vignesh', 46, 'Male', 28170.97, 'IT', '9647468723', 'Salem'),
# (19, 'Vignesh', 24, 'Male', 74838.04, 'IT', '9097882081', 'Madurai'),
# (20, 'Anitha', 25, 'Male', 47302.04, 'Logistics', '9399091699', 'Thanjavur'),
# (21, 'Preethi', 37, 'Male', 68578.08, 'Operations', '9346247510', 'Tirunelveli'),
# (22, 'Vanitha', 57, 'Male', 20860.86, 'Sales', '9842513542', 'Tirunelveli'),
# (23, 'Mala', 40, 'Male', 68429.06, 'R&D', '9412411824', 'Salem'),
# (24, 'Kamala', 34, 'Female', 31287.78, 'Marketing', '9874016400', 'Erode'),
# (25, 'Kishore', 29, 'Female', 27926.56, 'Support', '9868011280', 'Erode'),
# (26, 'Krishnan', 56, 'Male', 49382.94, 'IT', '9450533158', 'Vellore'),
# (27, 'Vanitha', 30, 'Male', 84168.46, 'Finance', '9602563421', 'Vellore'),
# (28, 'Divya', 51, 'Male', 30965.83, 'Support', '9543303654', 'Coimbatore'),
# (29, 'Kishore', 38, 'Female', 66318.54, 'Admin', '9850142940', 'Coimbatore'),
# (30, 'Baskar', 48, 'Female', 73283.6, 'Operations', '9698169340', 'Vellore'),
# (31, 'Gopal', 54, 'Male', 89046.01, 'R&D', '9356159514', 'Thanjavur'),
# (32, 'Rahul', 47, 'Female', 47192.03, 'Marketing', '9823662994', 'Vellore'),
# (33, 'Ravi', 21, 'Female', 37953.1, 'Admin', '9995777387', 'Madurai'),
# (34, 'Chandran', 26, 'Female', 56236.16, 'Logistics', '9513433200', 'Trichy'),
# (35, 'Prabhu', 25, 'Female', 48155.28, 'Logistics', '9367632016', 'Trichy'),
# (36, 'Bhavani', 54, 'Female', 19017.47, 'Sales', '9172788957', 'Tiruppur'),
# (37, 'Velan', 53, 'Female', 81445.53, 'R&D', '9727743487', 'Trichy'),
# (38, 'Ganesh', 49, 'Male', 72083.59, 'Sales', '9455812236', 'Madurai'),
# (39, 'Gopinath', 34, 'Male', 48189.43, 'Operations', '9876036690', 'Tiruppur'),
# (40, 'Malathi', 51, 'Male', 90419.33, 'Marketing', '9668893734', 'Vellore'),
# (41, 'Vasu', 22, 'Female', 41890.36, 'Admin', '9272980699', 'Chennai'),
# (42, 'Deepa', 48, 'Male', 84348.11, 'Finance', '9046537556', 'Salem'),
# (43, 'Subash', 47, 'Female', 81792.87, 'Support', '9080531003', 'Trichy'),
# (44, 'Priya', 30, 'Male', 25097.68, 'HR', '9937452991', 'Madurai'),
# (45, 'Rahul', 27, 'Male', 89310.97, 'Logistics', '9663193149', 'Coimbatore'),
# (46, 'Palani', 23, 'Female', 57619.62, 'Operations', '9185067165', 'Tirunelveli'),
# (47, 'Gopinath', 30, 'Female', 29090.96, 'R&D', '9498776945', 'Trichy'),
# (48, 'Manoj', 38, 'Female', 34509.08, 'Support', '9996507527', 'Trichy'),
# (49, 'Aravind', 37, 'Female', 37372.68, 'Logistics', '9480831367', 'Thanjavur'),
# (50, 'Nirmala', 36, 'Female', 66672.23, 'Support', '9701436349', 'Erode'),
# (51, 'Prabhu', 56, 'Female', 49040.31, 'R&D', '9557444313', 'Erode'),
# (52, 'Prakash', 55, 'Male', 30323.28, 'Support', '9498941343', 'Erode'),
# (53, 'Bhavani', 40, 'Male', 71641.48, 'Finance', '9400842710', 'Tiruppur'),
# (54, 'Kalpana', 51, 'Female', 50237.5, 'Finance', '9047116719', 'Chennai'),
# (55, 'Naveen', 30, 'Female', 21814.47, 'Sales', '9186999386', 'Tirunelveli'),
# (56, 'Murugan', 40, 'Female', 39430.42, 'Logistics', '9091334123', 'Madurai'),
# (57, 'Ravi', 25, 'Male', 15214.06, 'Support', '9974034471', 'Trichy'),
# (58, 'Dinesh', 58, 'Male', 49011.12, 'R&D', '9324210249', 'Tiruppur'),
# (59, 'Kalpana', 49, 'Male', 52495.84, 'Marketing', '9648877190', 'Vellore'),
# (60, 'Jayakumar', 41, 'Female', 17069.19, 'Sales', '9990490278', 'Tirunelveli'),
# (61, 'Ganesh', 32, 'Female', 65782.78, 'Support', '9175655125', 'Vellore'),
# (62, 'Raman', 52, 'Female', 68006.68, 'Admin', '9807154516', 'Thanjavur'),
# (63, 'Gopal', 55, 'Male', 51958.11, 'IT', '9385977034', 'Thanjavur'),
# (64, 'Sangeetha', 39, 'Female', 85467.73, 'Support', '9109324808', 'Vellore'),
# (65, 'Manoj', 35, 'Male', 51915.83, 'HR', '9274846773', 'Tirunelveli'),
# (66, 'Ravi', 30, 'Female', 30248.83, 'Logistics', '9821465840', 'Salem'),
# (67, 'Velan', 40, 'Female', 84220.85, 'Support', '9875588675', 'Trichy'),
# (68, 'Amudha', 36, 'Female', 33685.0, 'Admin', '9057662702', 'Thanjavur'),
# (69, 'Rani', 42, 'Male', 84935.23, 'Support', '9187026217', 'Salem'),
# (70, 'Muthu', 46, 'Male', 83141.22, 'R&D', '9657809134', 'Trichy'),
# (71, 'Leela', 26, 'Female', 93267.02, 'HR', '9724005045', 'Erode'),
# (72, 'Vidya', 30, 'Male', 57493.31, 'Logistics', '9222196937', 'Tiruppur'),
# (73, 'Meena', 35, 'Female', 66032.37, 'Support', '9407482175', 'Tiruppur'),
# (74, 'Sowmya', 48, 'Female', 51546.87, 'Marketing', '9367136959', 'Salem'),
# (75, 'Amudha', 39, 'Male', 93235.56, 'Admin', '9409097439', 'Erode'),
# (76, 'Shalini', 33, 'Female', 69221.16, 'Finance', '9104709521', 'Salem'),
# (77, 'Saravanan', 47, 'Male', 31063.58, 'R&D', '9588424745', 'Coimbatore'),
# (78, 'Rekha', 25, 'Male', 75332.12, 'Sales', '9685160481', 'Tirunelveli'),
# (79, 'Elango', 37, 'Female', 80793.38, 'Operations', '9137098593', 'Coimbatore'),
# (80, 'Saroja', 50, 'Female', 66939.16, 'HR', '9200471138', 'Madurai'),
# (81, 'Karthika', 50, 'Female', 68638.9, 'R&D', '9692617964', 'Chennai'),
# (82, 'Raman', 44, 'Male', 50470.65, 'Sales', '9515850643', 'Coimbatore'),
# (83, 'Anand', 26, 'Male', 66336.36, 'Logistics', '9005329318', 'Trichy'),
# (84, 'Rani', 34, 'Male', 41284.76, 'Finance', '9904228421', 'Chennai'),
# (85, 'Sangeetha', 21, 'Female', 78198.77, 'Sales', '9950240268', 'Coimbatore'),
# (86, 'Leela', 25, 'Female', 50862.02, 'Operations', '9891783908', 'Salem'),
# (87, 'Anand', 22, 'Male', 94886.94, 'Admin', '9617711592', 'Coimbatore'),
# (88, 'Sangeetha', 38, 'Female', 45472.35, 'Logistics', '9847896118', 'Trichy'),
# (89, 'Vidya', 49, 'Male', 48105.09, 'Support', '9661565452', 'Tirunelveli'),
# (90, 'Anitha', 26, 'Male', 22458.41, 'HR', '9528098851', 'Vellore'),
# (91, 'Aravind', 48, 'Male', 92471.89, 'Logistics', '9451983273', 'Coimbatore'),
# (92, 'Vasanthi', 56, 'Female', 24190.83, 'Marketing', '9936899809', 'Salem'),
# (93, 'Karthik', 32, 'Female', 71215.9, 'Marketing', '9550229612', 'Chennai'),
# (94, 'Manoj', 54, 'Male', 45095.55, 'Support', '9525459910', 'Madurai'),
# (95, 'Swathi', 24, 'Male', 36768.23, 'Admin', '9797643815', 'Vellore'),
# (96, 'Revathi', 39, 'Female', 57154.73, 'Marketing', '9036900343', 'Madurai'),
# (97, 'Nirmala', 37, 'Female', 41249.79, 'IT', '9762268388', 'Erode'),
# (98, 'Ramesh', 46, 'Male', 49897.57, 'Support', '9159696641', 'Vellore'),
# (99, 'Priya', 41, 'Male', 79105.77, 'Logistics', '9751613696', 'Thanjavur'),
# (100, 'Deepa', 46, 'Female', 74664.39, 'Sales', '9521818835', 'Erode');
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 100 rows affected.
# []

# %%
# %%sql
# select * from tp_930_de.Employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 100 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem'),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore'),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore'),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli'),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur'),
# ...

# %%
# %%sql
# select * from tp_930_de.Employees
# where Age = (select Age from tp_930_de.Employees where EmpID = 68);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 3 rows affected.
# [(17, 'Rekha', 36, 'Male', Decimal('50450.46'), 'R&D', '9108013267', 'Tirunelveli'),
#  (50, 'Nirmala', 36, 'Female', Decimal('66672.23'), 'Support', '9701436349', 'Erode'),
#  (68, 'Amudha', 36, 'Female', Decimal('33685.00'), 'Admin', '9057662702', 'Thanjavur')]

# %%
# %%sql
# create table tp_930_de.orders (
#     order_id int auto_increment primary key,
#     order_date date,
#     cust_name varchar(100),
#     order_amount decimal(10,2),
#     city varchar(100)
#     );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO tp_930_de.orders (order_date, cust_name, order_amount, city) VALUES
# ('2024-11-23', 'Priya Kumar', 7441.35, 'Mumbai'),
# ('2024-04-24', 'Suresh Raj', 6799.32, 'Hyderabad'),
# ('2024-02-14', 'Vikram Pillai', 414.65, 'Chennai'),
# ('2024-04-21', 'Meena Rao', 6059.99, 'Hyderabad'),
# ('2024-04-11', 'Pooja Pillai', 2282.36, 'Hyderabad'),
# ('2024-05-22', 'Arun Sharma', 7011.58, 'Delhi'),
# ('2024-05-22', 'Suresh Iyer', 9576.41, 'Delhi'),
# ('2024-02-22', 'Karthik Pillai', 1057.49, 'Delhi'),
# ('2024-11-05', 'Vijay Kumar', 7324.34, 'Hyderabad'),
# ('2024-03-04', 'Manoj Raj', 5565.2, 'Kolkata'),
# ('2024-11-12', 'Kavya Krishnan', 2003.66, 'Chennai'),
# ('2024-01-24', 'Meena Nair', 9853.69, 'Mumbai'),
# ('2024-02-21', 'Manoj Nair', 4588.76, 'Delhi'),
# ('2024-03-24', 'Kavya Reddy', 2174.12, 'Delhi'),
# ('2024-12-25', 'Karthik Krishnan', 6386.29, 'Hyderabad'),
# ('2024-05-05', 'Anitha Menon', 3856.61, 'Kolkata'),
# ('2024-12-18', 'Pooja Iyer', 6877.68, 'Chennai'),
# ('2024-04-27', 'Divya Reddy', 4071.53, 'Chennai'),
# ('2024-04-18', 'Vikram Reddy', 2205.0, 'Bangalore'),
# ('2024-07-21', 'Rajesh Sharma', 2722.31, 'Mumbai'),
# ('2024-10-14', 'Pooja Nair', 7495.44, 'Bangalore'),
# ('2024-10-25', 'Manoj Reddy', 2271.28, 'Mumbai'),
# ('2024-09-17', 'Deepa Raj', 7582.24, 'Chennai'),
# ('2024-03-19', 'Anitha Pillai', 6004.45, 'Bangalore'),
# ('2024-07-14', 'Nisha Menon', 5338.23, 'Hyderabad'),
# ('2024-01-06', 'Priya Rao', 7533.69, 'Kolkata'),
# ('2024-06-23', 'Priya Nair', 4404.18, 'Bangalore'),
# ('2024-01-02', 'Vijay Rao', 7643.43, 'Hyderabad'),
# ('2024-02-24', 'Lakshmi Rao', 6128.81, 'Mumbai'),
# ('2024-07-10', 'Anitha Rao', 9539.65, 'Hyderabad'),
# ('2024-01-01', 'Nisha Reddy', 4937.2, 'Chennai'),
# ('2024-07-04', 'Lakshmi Iyer', 673.46, 'Hyderabad'),
# ('2024-02-10', 'Karthik Menon', 8178.63, 'Hyderabad'),
# ('2024-03-05', 'Suresh Menon', 9473.8, 'Mumbai'),
# ('2024-05-15', 'Sanjay Krishnan', 4289.07, 'Mumbai'),
# ('2024-10-03', 'Ravi Nair', 4050.02, 'Kolkata'),
# ('2024-11-28', 'Kavya Menon', 9006.18, 'Bangalore'),
# ('2024-03-02', 'Meena Iyer', 733.86, 'Chennai'),
# ('2024-10-28', 'Pooja Iyer', 5925.56, 'Chennai'),
# ('2024-02-06', 'Divya Iyer', 767.26, 'Chennai'),
# ('2024-06-18', 'Karthik Rao', 2456.25, 'Kolkata'),
# ('2024-09-05', 'Ravi Rao', 1409.89, 'Hyderabad'),
# ('2024-10-22', 'Deepa Iyer', 7867.73, 'Bangalore'),
# ('2024-04-07', 'Priya Raj', 6623.93, 'Delhi'),
# ('2024-08-04', 'Sneha Menon', 8651.98, 'Chennai'),
# ('2024-12-10', 'Priya Kumar', 4085.95, 'Delhi'),
# ('2024-02-25', 'Meena Iyer', 1983.07, 'Bangalore'),
# ('2024-03-12', 'Sneha Sharma', 2857.6, 'Mumbai'),
# ('2024-02-08', 'Rajesh Rao', 1069.3, 'Kolkata'),
# ('2024-10-03', 'Arun Raj', 9271.03, 'Mumbai'),
# ('2024-03-26', 'Sneha Menon', 4865.45, 'Bangalore'),
# ('2024-01-31', 'Anitha Pillai', 121.34, 'Bangalore'),
# ('2024-05-15', 'Rajesh Nair', 4287.77, 'Kolkata'),
# ('2024-10-11', 'Deepa Sharma', 1979.99, 'Mumbai'),
# ('2024-01-30', 'Vikram Rao', 703.48, 'Delhi'),
# ('2024-01-30', 'Divya Krishnan', 4820.21, 'Hyderabad'),
# ('2024-03-21', 'Divya Rao', 893.1, 'Mumbai'),
# ('2024-02-05', 'Nisha Raj', 6784.6, 'Mumbai'),
# ('2024-07-25', 'Priya Krishnan', 2537.53, 'Hyderabad'),
# ('2024-01-21', 'Nisha Raj', 4250.33, 'Hyderabad'),
# ('2024-10-16', 'Sanjay Reddy', 9353.59, 'Mumbai'),
# ('2024-12-08', 'Ganesh Iyer', 2729.58, 'Mumbai'),
# ('2024-12-09', 'Lakshmi Menon', 3230.15, 'Chennai'),
# ('2024-01-05', 'Rajesh Krishnan', 9984.7, 'Chennai'),
# ('2024-02-07', 'Pooja Iyer', 5108.26, 'Mumbai'),
# ('2024-06-27', 'Karthik Iyer', 3758.32, 'Mumbai'),
# ('2024-08-12', 'Pooja Nair', 6155.61, 'Kolkata'),
# ('2024-09-27', 'Arun Rao', 3063.85, 'Kolkata'),
# ('2024-02-23', 'Suresh Nair', 1242.74, 'Chennai'),
# ('2024-10-10', 'Suresh Nair', 2889.39, 'Mumbai'),
# ('2024-06-24', 'Ravi Nair', 5103.55, 'Delhi'),
# ('2024-01-27', 'Karthik Pillai', 8310.55, 'Chennai'),
# ('2024-01-02', 'Ganesh Sharma', 6407.42, 'Delhi'),
# ('2024-03-23', 'Rajesh Rao', 7086.11, 'Hyderabad'),
# ('2024-01-05', 'Priya Raj', 9456.0, 'Kolkata'),
# ('2024-03-17', 'Pooja Kumar', 8362.49, 'Hyderabad'),
# ('2024-10-09', 'Suresh Pillai', 1361.71, 'Delhi'),
# ('2024-07-05', 'Divya Reddy', 2179.76, 'Mumbai'),
# ('2024-12-07', 'Priya Reddy', 7823.15, 'Bangalore'),
# ('2024-11-13', 'Suresh Iyer', 8659.6, 'Mumbai'),
# ('2024-07-30', 'Arun Sharma', 7391.99, 'Delhi'),
# ('2024-07-29', 'Meena Nair', 1676.06, 'Kolkata'),
# ('2024-02-25', 'Manoj Kumar', 8600.07, 'Mumbai'),
# ('2024-04-12', 'Rajesh Reddy', 3121.39, 'Mumbai'),
# ('2024-04-24', 'Arun Iyer', 4044.81, 'Delhi'),
# ('2024-02-05', 'Vijay Reddy', 6450.67, 'Bangalore'),
# ('2024-12-13', 'Pooja Reddy', 9398.45, 'Chennai'),
# ('2024-05-13', 'Anitha Krishnan', 9629.09, 'Delhi'),
# ('2024-01-20', 'Priya Krishnan', 4402.18, 'Kolkata'),
# ('2024-06-09', 'Sneha Krishnan', 9843.93, 'Chennai'),
# ('2024-07-16', 'Vikram Iyer', 2621.75, 'Kolkata'),
# ('2024-08-11', 'Arun Rao', 9263.19, 'Hyderabad'),
# ('2024-12-17', 'Ravi Reddy', 4369.84, 'Kolkata'),
# ('2024-06-18', 'Nisha Reddy', 6667.54, 'Chennai'),
# ('2024-06-02', 'Sanjay Nair', 6702.24, 'Delhi'),
# ('2024-07-25', 'Lakshmi Rao', 1360.15, 'Bangalore'),
# ('2024-12-06', 'Manoj Sharma', 6193.6, 'Delhi'),
# ('2024-07-26', 'Pooja Kumar', 3108.36, 'Mumbai'),
# ('2024-08-08', 'Vikram Krishnan', 6581.59, 'Bangalore'),
# ('2024-08-14', 'Rajesh Iyer', 5160.62, 'Kolkata'),
# ('2024-03-27', 'Karthik Nair', 5202.97, 'Kolkata'),
# ('2024-11-13', 'Ganesh Raj', 8202.39, 'Mumbai'),
# ('2024-12-10', 'Lakshmi Iyer', 8084.97, 'Mumbai'),
# ('2024-01-13', 'Divya Iyer', 9840.97, 'Hyderabad'),
# ('2024-02-07', 'Rajesh Pillai', 8872.76, 'Hyderabad'),
# ('2024-04-09', 'Manoj Menon', 4056.56, 'Mumbai'),
# ('2024-12-01', 'Arun Raj', 7806.36, 'Mumbai'),
# ('2024-03-31', 'Sanjay Menon', 597.16, 'Mumbai'),
# ('2024-03-03', 'Rajesh Sharma', 8034.02, 'Kolkata'),
# ('2024-09-28', 'Pooja Krishnan', 3241.25, 'Bangalore'),
# ('2024-11-09', 'Sanjay Pillai', 8322.63, 'Hyderabad'),
# ('2024-08-16', 'Anitha Menon', 4555.69, 'Mumbai'),
# ('2024-11-22', 'Vijay Rao', 4897.51, 'Mumbai'),
# ('2024-05-20', 'Rajesh Raj', 7164.09, 'Mumbai'),
# ('2024-05-19', 'Ganesh Reddy', 8940.97, 'Chennai'),
# ('2024-03-11', 'Suresh Iyer', 3892.05, 'Mumbai'),
# ('2024-12-27', 'Ravi Raj', 4207.19, 'Delhi'),
# ('2024-10-04', 'Rajesh Pillai', 716.43, 'Bangalore'),
# ('2024-07-18', 'Vikram Kumar', 8581.65, 'Hyderabad'),
# ('2024-07-13', 'Deepa Kumar', 9433.14, 'Delhi'),
# ('2024-07-18', 'Sneha Rao', 7500.41, 'Hyderabad'),
# ('2024-11-04', 'Meena Menon', 2272.27, 'Bangalore'),
# ('2024-09-05', 'Arun Pillai', 3427.68, 'Kolkata'),
# ('2024-07-26', 'Anitha Menon', 9203.46, 'Hyderabad'),
# ('2024-09-30', 'Arun Pillai', 5959.74, 'Kolkata'),
# ('2024-01-14', 'Karthik Pillai', 1443.42, 'Bangalore'),
# ('2024-04-03', 'Divya Nair', 3853.13, 'Mumbai'),
# ('2024-08-20', 'Ganesh Reddy', 7636.17, 'Bangalore'),
# ('2024-05-22', 'Sneha Nair', 8365.62, 'Bangalore'),
# ('2024-01-10', 'Pooja Kumar', 9999.09, 'Delhi'),
# ('2024-04-24', 'Karthik Kumar', 7566.91, 'Mumbai'),
# ('2024-04-12', 'Arun Krishnan', 1608.59, 'Mumbai'),
# ('2024-08-30', 'Priya Krishnan', 9482.79, 'Bangalore'),
# ('2024-12-24', 'Vijay Reddy', 1761.11, 'Hyderabad'),
# ('2024-02-28', 'Anitha Nair', 1170.18, 'Chennai'),
# ('2024-06-08', 'Vikram Pillai', 4026.88, 'Kolkata'),
# ('2024-04-11', 'Karthik Krishnan', 6937.08, 'Kolkata'),
# ('2024-05-04', 'Priya Nair', 8517.9, 'Hyderabad'),
# ('2024-03-02', 'Vikram Kumar', 3537.32, 'Bangalore'),
# ('2024-12-04', 'Kavya Raj', 5109.01, 'Delhi'),
# ('2024-01-07', 'Sneha Menon', 1144.83, 'Delhi'),
# ('2024-11-21', 'Rajesh Sharma', 4411.32, 'Kolkata'),
# ('2024-09-24', 'Vijay Krishnan', 8101.17, 'Hyderabad'),
# ('2024-09-04', 'Rajesh Pillai', 8274.77, 'Hyderabad'),
# ('2024-05-17', 'Ganesh Iyer', 8324.24, 'Chennai'),
# ('2024-05-22', 'Rajesh Iyer', 7529.72, 'Hyderabad'),
# ('2024-11-08', 'Manoj Reddy', 384.13, 'Delhi'),
# ('2024-04-03', 'Deepa Iyer', 3612.77, 'Delhi'),
# ('2024-06-23', 'Vijay Krishnan', 7041.72, 'Delhi'),
# ('2024-10-11', 'Arun Rao', 9485.82, 'Chennai'),
# ('2024-05-03', 'Sneha Menon', 5596.24, 'Mumbai'),
# ('2024-12-19', 'Deepa Menon', 4536.93, 'Chennai'),
# ('2024-02-17', 'Lakshmi Iyer', 4103.57, 'Mumbai'),
# ('2024-06-05', 'Vikram Reddy', 4785.28, 'Hyderabad'),
# ('2024-06-25', 'Sneha Rao', 3374.83, 'Kolkata'),
# ('2024-08-20', 'Vijay Nair', 2588.9, 'Chennai'),
# ('2024-04-08', 'Ganesh Raj', 7454.52, 'Kolkata'),
# ('2024-04-04', 'Ravi Iyer', 7412.19, 'Delhi'),
# ('2024-10-28', 'Sanjay Krishnan', 2901.69, 'Chennai'),
# ('2024-04-09', 'Lakshmi Iyer', 3672.72, 'Delhi'),
# ('2024-01-08', 'Pooja Sharma', 2815.68, 'Chennai'),
# ('2024-10-10', 'Lakshmi Sharma', 6414.91, 'Bangalore'),
# ('2024-02-22', 'Arun Krishnan', 2914.96, 'Bangalore'),
# ('2024-08-13', 'Ganesh Sharma', 9658.43, 'Delhi'),
# ('2024-09-01', 'Priya Raj', 4067.0, 'Chennai'),
# ('2024-10-22', 'Divya Sharma', 1577.06, 'Hyderabad'),
# ('2024-06-04', 'Karthik Iyer', 1272.67, 'Bangalore'),
# ('2024-11-06', 'Nisha Krishnan', 2334.3, 'Hyderabad'),
# ('2024-07-13', 'Rajesh Menon', 3043.8, 'Hyderabad'),
# ('2024-08-07', 'Lakshmi Krishnan', 6248.17, 'Hyderabad'),
# ('2024-02-20', 'Ravi Iyer', 2720.0, 'Chennai'),
# ('2024-03-21', 'Meena Sharma', 5564.72, 'Mumbai'),
# ('2024-01-02', 'Sneha Menon', 6924.77, 'Bangalore'),
# ('2024-05-29', 'Divya Iyer', 2952.24, 'Delhi'),
# ('2024-12-25', 'Rajesh Raj', 6905.11, 'Delhi'),
# ('2024-11-16', 'Vikram Iyer', 4308.88, 'Hyderabad'),
# ('2024-04-25', 'Suresh Nair', 8283.65, 'Chennai'),
# ('2024-01-31', 'Anitha Nair', 5990.94, 'Hyderabad'),
# ('2024-05-27', 'Rajesh Raj', 4740.11, 'Delhi'),
# ('2024-12-24', 'Manoj Nair', 5054.67, 'Bangalore'),
# ('2024-08-12', 'Karthik Krishnan', 494.62, 'Bangalore'),
# ('2024-06-14', 'Nisha Nair', 356.06, 'Mumbai'),
# ('2024-12-11', 'Vikram Krishnan', 9512.78, 'Kolkata'),
# ('2024-05-17', 'Vikram Kumar', 7654.78, 'Mumbai'),
# ('2024-08-28', 'Sanjay Menon', 9169.12, 'Mumbai'),
# ('2024-10-26', 'Sneha Menon', 9693.65, 'Bangalore'),
# ('2024-06-27', 'Sneha Reddy', 3278.48, 'Chennai'),
# ('2024-03-23', 'Ganesh Pillai', 6967.37, 'Delhi'),
# ('2024-12-05', 'Manoj Rao', 463.3, 'Chennai'),
# ('2024-06-10', 'Vijay Reddy', 1247.62, 'Bangalore'),
# ('2024-09-20', 'Arun Rao', 4673.57, 'Chennai'),
# ('2024-04-06', 'Sanjay Reddy', 6264.08, 'Bangalore'),
# ('2024-11-16', 'Rajesh Kumar', 2115.23, 'Hyderabad'),
# ('2024-03-08', 'Lakshmi Menon', 8820.38, 'Bangalore'),
# ('2024-03-03', 'Arun Krishnan', 8013.21, 'Kolkata'),
# ('2024-03-22', 'Lakshmi Rao', 235.38, 'Bangalore'),
# ('2024-02-17', 'Meena Raj', 4668.33, 'Chennai'),
# ('2024-11-27', 'Suresh Menon', 9333.27, 'Delhi'),
# ('2024-09-17', 'Vijay Pillai', 8363.77, 'Bangalore'),
# ('2024-05-04', 'Rajesh Rao', 1531.96, 'Mumbai'),
# ('2024-11-02', 'Sanjay Sharma', 8653.87, 'Delhi'),
# ('2024-07-31', 'Ganesh Rao', 2745.01, 'Chennai'),
# ('2024-05-24', 'Lakshmi Krishnan', 5841.24, 'Kolkata'),
# ('2024-09-07', 'Suresh Menon', 5431.95, 'Delhi'),
# ('2024-06-19', 'Pooja Rao', 3834.38, 'Delhi'),
# ('2024-04-06', 'Meena Krishnan', 3891.41, 'Bangalore'),
# ('2024-01-23', 'Ganesh Menon', 7081.76, 'Bangalore'),
# ('2024-07-16', 'Suresh Menon', 9651.76, 'Mumbai'),
# ('2024-09-14', 'Vikram Reddy', 8710.03, 'Bangalore'),
# ('2024-02-21', 'Sanjay Menon', 251.94, 'Mumbai'),
# ('2024-07-28', 'Suresh Raj', 4747.96, 'Delhi'),
# ('2024-06-22', 'Nisha Pillai', 6533.38, 'Delhi'),
# ('2024-12-11', 'Pooja Pillai', 9545.98, 'Kolkata'),
# ('2024-09-06', 'Pooja Kumar', 6212.85, 'Mumbai'),
# ('2024-11-19', 'Lakshmi Iyer', 7492.99, 'Bangalore'),
# ('2024-02-20', 'Priya Menon', 1747.01, 'Delhi'),
# ('2024-01-15', 'Divya Reddy', 7981.82, 'Delhi'),
# ('2024-07-02', 'Kavya Pillai', 1541.14, 'Hyderabad'),
# ('2024-07-29', 'Vikram Sharma', 1782.84, 'Chennai'),
# ('2024-11-08', 'Manoj Krishnan', 6863.03, 'Bangalore'),
# ('2024-10-25', 'Suresh Iyer', 4665.38, 'Delhi'),
# ('2024-08-23', 'Vijay Kumar', 8999.19, 'Bangalore'),
# ('2024-05-27', 'Pooja Sharma', 831.23, 'Delhi'),
# ('2024-10-27', 'Lakshmi Pillai', 6934.1, 'Bangalore'),
# ('2024-06-03', 'Ravi Pillai', 8548.02, 'Chennai'),
# ('2024-05-01', 'Manoj Krishnan', 3653.7, 'Delhi'),
# ('2024-12-24', 'Lakshmi Kumar', 9781.65, 'Kolkata'),
# ('2024-07-21', 'Vijay Kumar', 5702.7, 'Kolkata'),
# ('2024-01-26', 'Nisha Menon', 8345.11, 'Delhi'),
# ('2024-04-27', 'Nisha Reddy', 2268.14, 'Mumbai'),
# ('2024-11-13', 'Vijay Sharma', 6319.66, 'Kolkata'),
# ('2024-11-26', 'Divya Nair', 7907.24, 'Chennai'),
# ('2024-10-23', 'Kavya Sharma', 992.32, 'Delhi'),
# ('2024-06-16', 'Sneha Sharma', 2087.87, 'Hyderabad'),
# ('2024-07-06', 'Sanjay Rao', 9143.52, 'Mumbai'),
# ('2024-05-11', 'Deepa Nair', 7490.94, 'Delhi'),
# ('2024-02-28', 'Rajesh Raj', 1493.49, 'Mumbai'),
# ('2024-12-12', 'Manoj Rao', 3721.17, 'Bangalore'),
# ('2024-01-08', 'Vijay Rao', 1323.53, 'Delhi'),
# ('2024-12-10', 'Vijay Krishnan', 3872.15, 'Kolkata'),
# ('2024-07-09', 'Priya Iyer', 4767.62, 'Hyderabad'),
# ('2024-10-14', 'Ganesh Krishnan', 2291.54, 'Chennai'),
# ('2024-11-21', 'Rajesh Nair', 6527.47, 'Chennai'),
# ('2024-03-12', 'Divya Kumar', 3113.21, 'Bangalore'),
# ('2024-02-29', 'Priya Iyer', 8883.87, 'Mumbai'),
# ('2024-07-17', 'Rajesh Reddy', 6737.81, 'Kolkata'),
# ('2024-12-22', 'Pooja Pillai', 5914.67, 'Kolkata'),
# ('2024-03-20', 'Sneha Raj', 8353.56, 'Hyderabad'),
# ('2024-07-27', 'Vijay Kumar', 6933.78, 'Mumbai'),
# ('2024-08-15', 'Rajesh Iyer', 8568.96, 'Chennai'),
# ('2024-12-17', 'Kavya Rao', 9026.79, 'Kolkata'),
# ('2024-07-02', 'Divya Pillai', 2831.23, 'Chennai'),
# ('2024-08-20', 'Karthik Iyer', 6452.87, 'Hyderabad'),
# ('2024-01-11', 'Divya Reddy', 2511.33, 'Mumbai'),
# ('2024-10-16', 'Ravi Raj', 8315.2, 'Hyderabad'),
# ('2024-04-16', 'Vikram Iyer', 8149.22, 'Mumbai'),
# ('2024-06-17', 'Suresh Krishnan', 128.07, 'Mumbai'),
# ('2024-03-07', 'Pooja Nair', 8005.29, 'Chennai'),
# ('2024-12-04', 'Arun Sharma', 247.12, 'Mumbai'),
# ('2024-10-28', 'Ganesh Kumar', 1825.04, 'Chennai'),
# ('2024-03-05', 'Sneha Rao', 1225.13, 'Chennai'),
# ('2024-08-31', 'Rajesh Reddy', 5181.06, 'Chennai'),
# ('2024-08-19', 'Sanjay Iyer', 9459.61, 'Chennai'),
# ('2024-12-03', 'Sanjay Nair', 4634.62, 'Chennai'),
# ('2024-02-01', 'Deepa Pillai', 4320.11, 'Chennai'),
# ('2024-09-08', 'Rajesh Raj', 9002.74, 'Delhi'),
# ('2024-11-07', 'Suresh Raj', 1349.3, 'Hyderabad'),
# ('2024-11-20', 'Vikram Rao', 7150.31, 'Bangalore'),
# ('2024-11-01', 'Sanjay Nair', 4591.78, 'Hyderabad'),
# ('2024-08-08', 'Priya Raj', 8542.65, 'Kolkata'),
# ('2024-10-09', 'Ravi Pillai', 4570.39, 'Mumbai'),
# ('2024-07-30', 'Ganesh Menon', 4047.43, 'Kolkata'),
# ('2024-02-18', 'Ganesh Pillai', 3193.98, 'Delhi'),
# ('2024-07-10', 'Suresh Menon', 764.62, 'Chennai'),
# ('2024-02-17', 'Sneha Raj', 7471.43, 'Delhi'),
# ('2024-03-07', 'Pooja Kumar', 5906.0, 'Hyderabad'),
# ('2024-10-14', 'Ganesh Raj', 4167.01, 'Kolkata'),
# ('2024-08-04', 'Divya Nair', 6044.06, 'Delhi'),
# ('2024-02-23', 'Vikram Rao', 2206.11, 'Kolkata'),
# ('2024-09-03', 'Meena Raj', 3566.13, 'Hyderabad'),
# ('2024-07-07', 'Priya Nair', 5783.59, 'Bangalore'),
# ('2024-10-14', 'Nisha Krishnan', 6782.27, 'Hyderabad'),
# ('2024-01-14', 'Nisha Nair', 386.64, 'Delhi'),
# ('2024-12-25', 'Lakshmi Reddy', 3575.13, 'Mumbai'),
# ('2024-03-14', 'Vikram Pillai', 788.9, 'Kolkata'),
# ('2024-11-20', 'Arun Raj', 7486.51, 'Mumbai'),
# ('2024-07-11', 'Sneha Menon', 3474.87, 'Delhi'),
# ('2024-06-08', 'Ganesh Krishnan', 6002.62, 'Chennai'),
# ('2024-03-20', 'Anitha Krishnan', 592.65, 'Chennai'),
# ('2024-05-19', 'Rajesh Pillai', 4908.05, 'Bangalore'),
# ('2024-07-31', 'Vijay Iyer', 7573.94, 'Chennai'),
# ('2024-06-25', 'Sneha Raj', 2904.14, 'Kolkata'),
# ('2024-10-30', 'Deepa Rao', 6704.61, 'Chennai'),
# ('2024-04-22', 'Manoj Krishnan', 642.34, 'Mumbai'),
# ('2024-06-03', 'Ravi Sharma', 7665.19, 'Delhi'),
# ('2024-06-16', 'Priya Kumar', 5024.11, 'Bangalore'),
# ('2024-03-30', 'Suresh Pillai', 5372.57, 'Mumbai'),
# ('2024-09-13', 'Pooja Reddy', 813.55, 'Kolkata'),
# ('2024-01-22', 'Sneha Kumar', 4651.57, 'Chennai');
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 299 rows affected.
# []

# %%
# %%sql
# select * from tp_930_de.Employees
# where Location in (
#     select distinct city from tp_930_de.orders
#     where order_amount > 9500
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 6 rows affected.
# [(15, 'Mala', 29, 'Female', Decimal('34439.78'), 'Support', '9631165667', 'Chennai'),
#  (41, 'Vasu', 22, 'Female', Decimal('41890.36'), 'Admin', '9272980699', 'Chennai'),
#  (54, 'Kalpana', 51, 'Female', Decimal('50237.50'), 'Finance', '9047116719', 'Chennai'),
#  (81, 'Karthika', 50, 'Female', Decimal('68638.90'), 'R&D', '9692617964', 'Chennai'),
#  (84, 'Rani', 34, 'Male', Decimal('41284.76'), 'Finance', '9904228421', 'Chennai'),
#  (93, 'Karthik', 32, 'Female', Decimal('71215.90'), 'Marketing', '9550229612', 'Chennai')]

# %%
# %%sql
# select * from tp_930_de.Employees e1
# where salary > (
#     select avg(salary)
#     from tp_930_de.Employees e2
#     where e2.department = e1.department);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 47 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur'),
#  (11, 'Tamil', 54, 'Male', Decimal('62915.57'), 'Support', '9015430391', 'Coimbatore'),
#  (12, 'Parvathi', 52, 'Male', Decimal('93238.76'), 'R&D', '9227824896', 'Trichy'),
#  (19, 'Vignesh', 24, 'Male', Decimal('74838.04'), 'IT', '9097882081', 'Madurai'),
#  (21, 'Preethi', 37, 'Male', Decimal('68578.08'), 'Operations', '9346247510', 'Tirunelveli'),
#  (23, 'Mala', 40, 'Male', Decimal('68429.06'), 'R&D', '9412411824', 'Salem'),
# ...

# %%
# %%sql
# select * from tp_930_de.Employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 100 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem'),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore'),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore'),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli'),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur'),
# ...

# %%
# %%sql
# select * from tp_930_de.Employees
# limit 80,10;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 10 rows affected.
# [(81, 'Karthika', 50, 'Female', Decimal('68638.90'), 'R&D', '9692617964', 'Chennai'),
#  (82, 'Raman', 44, 'Male', Decimal('50470.65'), 'Sales', '9515850643', 'Coimbatore'),
#  (83, 'Anand', 26, 'Male', Decimal('66336.36'), 'Logistics', '9005329318', 'Trichy'),
#  (84, 'Rani', 34, 'Male', Decimal('41284.76'), 'Finance', '9904228421', 'Chennai'),
#  (85, 'Sangeetha', 21, 'Female', Decimal('78198.77'), 'Sales', '9950240268', 'Coimbatore'),
#  (86, 'Leela', 25, 'Female', Decimal('50862.02'), 'Operations', '9891783908', 'Salem'),
#  (87, 'Anand', 22, 'Male', Decimal('94886.94'), 'Admin', '9617711592', 'Coimbatore'),
#  (88, 'Sangeetha', 38, 'Female', Decimal('45472.35'), 'Logistics', '9847896118', 'Trichy'),
#  (89, 'Vidya', 49, 'Male', Decimal('48105.09'), 'Support', '9661565452', 'Tirunelveli'),
#  (90, 'Anitha', 26, 'Male', Decimal('22458.41'), 'HR', '9528098851', 'Vellore')]

# %% [markdown]
# #### Where

# %%
# %%sql
# select * from tp_930_de.Employees
# where age = 50;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 3 rows affected.
# [(6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy'),
#  (80, 'Saroja', 50, 'Female', Decimal('66939.16'), 'HR', '9200471138', 'Madurai'),
#  (81, 'Karthika', 50, 'Female', Decimal('68638.90'), 'R&D', '9692617964', 'Chennai')]

# %% [markdown]
# #### Greater than >

# %%
# %%sql
# Select * from tp_930_de.Employees
# where salary > 20000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 96 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem'),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore'),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore'),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli'),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur'),
# ...

# %% [markdown]
# #### Lesser than

# %%
# %%sql
# select * from tp_930_de.Employees
# where salary < 20000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 4 rows affected.
# [(14, 'Ravi', 35, 'Male', Decimal('15575.27'), 'IT', '9310518347', 'Trichy'),
#  (36, 'Bhavani', 54, 'Female', Decimal('19017.47'), 'Sales', '9172788957', 'Tiruppur'),
#  (57, 'Ravi', 25, 'Male', Decimal('15214.06'), 'Support', '9974034471', 'Trichy'),
#  (60, 'Jayakumar', 41, 'Female', Decimal('17069.19'), 'Sales', '9990490278', 'Tirunelveli')]

# %%
# %%sql
# select * from tp_930_de.Employees
# where department != "HR";
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 95 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem'),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore'),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore'),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli'),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur'),
# ...

# %%
# %%sql
# select * from tp_930_de.Employees
# where department <> "Sales";
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 90 rows affected.
# [(2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem'),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore'),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore'),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli'),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur'),
#  (11, 'Tamil', 54, 'Male', Decimal('62915.57'), 'Support', '9015430391', 'Coimbatore'),
# ...

# %% [markdown]
# #### And

# %%
# %%sql
# select * from tp_930_de.Employees
# where Department = "IT" and
#     Salary > 60000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 1 rows affected.
# [(19, 'Vignesh', 24, 'Male', Decimal('74838.04'), 'IT', '9097882081', 'Madurai')]

# %%
# %%sql
# select * from tp_930_de.Employees
# where department = "Sales" and
#     salary > 50000 and
#     Location = "Coimbatore";
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 3 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (82, 'Raman', 44, 'Male', Decimal('50470.65'), 'Sales', '9515850643', 'Coimbatore'),
#  (85, 'Sangeetha', 21, 'Female', Decimal('78198.77'), 'Sales', '9950240268', 'Coimbatore')]

# %%
# %%sql
# select * from tp_930_de.Employees
# where department = "IT" or
#     location = "Chennai";
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 12 rows affected.
# [(14, 'Ravi', 35, 'Male', Decimal('15575.27'), 'IT', '9310518347', 'Trichy'),
#  (15, 'Mala', 29, 'Female', Decimal('34439.78'), 'Support', '9631165667', 'Chennai'),
#  (18, 'Vignesh', 46, 'Male', Decimal('28170.97'), 'IT', '9647468723', 'Salem'),
#  (19, 'Vignesh', 24, 'Male', Decimal('74838.04'), 'IT', '9097882081', 'Madurai'),
#  (26, 'Krishnan', 56, 'Male', Decimal('49382.94'), 'IT', '9450533158', 'Vellore'),
#  (41, 'Vasu', 22, 'Female', Decimal('41890.36'), 'Admin', '9272980699', 'Chennai'),
#  (54, 'Kalpana', 51, 'Female', Decimal('50237.50'), 'Finance', '9047116719', 'Chennai'),
#  (63, 'Gopal', 55, 'Male', Decimal('51958.11'), 'IT', '9385977034', 'Thanjavur'),
#  (81, 'Karthika', 50, 'Female', Decimal('68638.90'), 'R&D', '9692617964', 'Chennai'),
#  (84, 'Rani', 34, 'Male', Decimal('41284.76'), 'Finance', '9904228421', 'Chennai'),
# ...

# %%
# %%sql
# select * from tp_930_de.Employees
# where department in ("IT", "Sales");
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 16 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (14, 'Ravi', 35, 'Male', Decimal('15575.27'), 'IT', '9310518347', 'Trichy'),
#  (18, 'Vignesh', 46, 'Male', Decimal('28170.97'), 'IT', '9647468723', 'Salem'),
#  (19, 'Vignesh', 24, 'Male', Decimal('74838.04'), 'IT', '9097882081', 'Madurai'),
#  (22, 'Vanitha', 57, 'Male', Decimal('20860.86'), 'Sales', '9842513542', 'Tirunelveli'),
#  (26, 'Krishnan', 56, 'Male', Decimal('49382.94'), 'IT', '9450533158', 'Vellore'),
#  (36, 'Bhavani', 54, 'Female', Decimal('19017.47'), 'Sales', '9172788957', 'Tiruppur'),
#  (38, 'Ganesh', 49, 'Male', Decimal('72083.59'), 'Sales', '9455812236', 'Madurai'),
#  (55, 'Naveen', 30, 'Female', Decimal('21814.47'), 'Sales', '9186999386', 'Tirunelveli'),
#  (60, 'Jayakumar', 41, 'Female', Decimal('17069.19'), 'Sales', '9990490278', 'Tirunelveli'),
# ...

# %%
# %%sql
# select * from tp_930_de.Employees
# where department not in ("IT", "Sales")
# limit 5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 5 rows affected.
# [(2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem'),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore'),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy')]

# %%
# %%sql
# select * from tp_930_de.Employees
# where salary between 30000 and 50000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 30 rows affected.
# [(6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy'),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore'),
#  (13, 'Mala', 33, 'Female', Decimal('46919.38'), 'Operations', '9787133150', 'Tiruppur'),
#  (15, 'Mala', 29, 'Female', Decimal('34439.78'), 'Support', '9631165667', 'Chennai'),
#  (16, 'Selva', 27, 'Male', Decimal('47209.70'), 'Operations', '9133387262', 'Salem'),
#  (20, 'Anitha', 25, 'Male', Decimal('47302.04'), 'Logistics', '9399091699', 'Thanjavur'),
#  (24, 'Kamala', 34, 'Female', Decimal('31287.78'), 'Marketing', '9874016400', 'Erode'),
#  (26, 'Krishnan', 56, 'Male', Decimal('49382.94'), 'IT', '9450533158', 'Vellore'),
#  (28, 'Divya', 51, 'Male', Decimal('30965.83'), 'Support', '9543303654', 'Coimbatore'),
#  (32, 'Rahul', 47, 'Female', Decimal('47192.03'), 'Marketing', '9823662994', 'Vellore'),
# ...

# %%
# %%sql
# select * from tp_930_de.Employees
# where department like '%ra%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 9 rows affected.
# [(5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (13, 'Mala', 33, 'Female', Decimal('46919.38'), 'Operations', '9787133150', 'Tiruppur'),
#  (16, 'Selva', 27, 'Male', Decimal('47209.70'), 'Operations', '9133387262', 'Salem'),
#  (21, 'Preethi', 37, 'Male', Decimal('68578.08'), 'Operations', '9346247510', 'Tirunelveli'),
#  (30, 'Baskar', 48, 'Female', Decimal('73283.60'), 'Operations', '9698169340', 'Vellore'),
#  (39, 'Gopinath', 34, 'Male', Decimal('48189.43'), 'Operations', '9876036690', 'Tiruppur'),
#  (46, 'Palani', 23, 'Female', Decimal('57619.62'), 'Operations', '9185067165', 'Tirunelveli'),
#  (79, 'Elango', 37, 'Female', Decimal('80793.38'), 'Operations', '9137098593', 'Coimbatore'),
#  (86, 'Leela', 25, 'Female', Decimal('50862.02'), 'Operations', '9891783908', 'Salem')]

# %%
# %%sql
# select * from tp_930_de.Employees
# where name like 'a%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 8 rows affected.
# [(20, 'Anitha', 25, 'Male', Decimal('47302.04'), 'Logistics', '9399091699', 'Thanjavur'),
#  (49, 'Aravind', 37, 'Female', Decimal('37372.68'), 'Logistics', '9480831367', 'Thanjavur'),
#  (68, 'Amudha', 36, 'Female', Decimal('33685.00'), 'Admin', '9057662702', 'Thanjavur'),
#  (75, 'Amudha', 39, 'Male', Decimal('93235.56'), 'Admin', '9409097439', 'Erode'),
#  (83, 'Anand', 26, 'Male', Decimal('66336.36'), 'Logistics', '9005329318', 'Trichy'),
#  (87, 'Anand', 22, 'Male', Decimal('94886.94'), 'Admin', '9617711592', 'Coimbatore'),
#  (90, 'Anitha', 26, 'Male', Decimal('22458.41'), 'HR', '9528098851', 'Vellore'),
#  (91, 'Aravind', 48, 'Male', Decimal('92471.89'), 'Logistics', '9451983273', 'Coimbatore')]

# %%
# %%sql
# select * from tp_930_de.Employees
# where name like ('_a%');
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 45 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli'),
#  (11, 'Tamil', 54, 'Male', Decimal('62915.57'), 'Support', '9015430391', 'Coimbatore'),
#  (12, 'Parvathi', 52, 'Male', Decimal('93238.76'), 'R&D', '9227824896', 'Trichy'),
#  (13, 'Mala', 33, 'Female', Decimal('46919.38'), 'Operations', '9787133150', 'Tiruppur'),
#  (14, 'Ravi', 35, 'Male', Decimal('15575.27'), 'IT', '9310518347', 'Trichy'),
#  (15, 'Mala', 29, 'Female', Decimal('34439.78'), 'Support', '9631165667', 'Chennai'),
# ...

# %%
# %%sql
# select * from tp_930_de.Employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/
# 100 rows affected.
# [(1, 'Saroja', 28, 'Male', Decimal('74324.04'), 'Sales', '9321819600', 'Coimbatore'),
#  (2, 'Vignesh', 35, 'Male', Decimal('59899.61'), 'R&D', '9637940265', 'Salem'),
#  (3, 'Naveen', 34, 'Female', Decimal('23176.82'), 'Admin', '9155940781', 'Vellore'),
#  (4, 'Deepa', 56, 'Female', Decimal('81352.37'), 'Logistics', '9593103413', 'Coimbatore'),
#  (5, 'Malathi', 38, 'Female', Decimal('65854.76'), 'Operations', '9255341928', 'Trichy'),
#  (6, 'Swathi', 50, 'Female', Decimal('36595.83'), 'R&D', '9350305641', 'Trichy'),
#  (7, 'Palani', 41, 'Male', Decimal('67435.09'), 'Admin', '9724238849', 'Vellore'),
#  (8, 'Krishnan', 46, 'Female', Decimal('32545.66'), 'Finance', '9871012269', 'Coimbatore'),
#  (9, 'Karthika', 45, 'Female', Decimal('57329.15'), 'R&D', '9018451462', 'Tirunelveli'),
#  (10, 'Gopal', 37, 'Male', Decimal('92751.05'), 'Finance', '9814893252', 'Thanjavur'),
# ...
